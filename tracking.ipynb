# %%
from ultralytics import *
# Out:
# /Users/claudia/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# Available models:
# - general_best.pt
# - cuban_rand.pt
# - cuban_sim.pt

# %%
model = YOLO(model='models/cuban_sim.pt')

# %%
results = model.track('datasets/road_m.mp4', tracker="bytetrack.yaml", save=True, conf=0.70)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1178) /Users/claudia/Desktop/Recognition-of-traffic-signals/datasets/road_m.mp4: 384x640 (no detections), 52.8ms
# video 1/1 (frame 2/1178) /Users/claudia/Desktop/Recognition-of-traffic-signals/datasets/road_m.mp4: 384x640 (no detections), 52.0ms
# video 1/1 (frame 3/1178) /Users/claudia/Desktop/Recognition-of-traffic-signals/datasets/road_m.mp4: 384x640 (no detections), 51.4ms
# ...
